# %% [markdown]
# ## Input

# %%
import pandas as pd

# %% [markdown]
# - ### csv

# %%
df_csv = pd.read_csv('foodtracer_nightmarket_merge_utf8.csv')

# %%
df_csv.head()
# Out:
#     夜市名稱   攤商名稱              攤位 調味名稱          品牌                  來源(產地)
# 0  南機場夜市  正宗福州麵      中華路二段315巷口    薑        青禾商行  臺北市萬華區國興路52號1樓(青年公園附近)
# 1  南機場夜市  黑嚕嚕粉圓  中華路二段307-309巷間   黑糖      黑嚕嚕粉圓店    台中市大里區仁德里四維街29巷15號1樓
# 2  南機場夜市   肉羹涼麵  中華路二段309-311巷間   冰糖  台灣糖業股份有限公司      台南市仁德區田厝里文華路2段326號
# 3  南機場夜市   肉羹涼麵  中華路二段309-311巷間   香油    辰邦股份有限公司        新北市新莊區化成路403巷47號
# 4  南機場夜市   肉羹涼麵  中華路二段309-311巷間   醬油  金蘭食品股份有限公司           桃園市大溪區介壽路236號

# %% [markdown]
# - ### json

# %% [markdown]
#     - 注意orient

# %%
df_json = pd.read_json('foodtracer_nightmarket_merge.json')

# %%
df_json
# Out:
#                           0                     1                   2     \
# 夜市名稱                     南機場夜市                 南機場夜市               南機場夜市
# 攤商名稱                     正宗福州麵                 黑嚕嚕粉圓                肉羹涼麵
# 攤位                  中華路二段315巷口        中華路二段307-309巷間      中華路二段309-311巷間
# 調味名稱                         薑                    黑糖                  冰糖
# 品牌                        青禾商行                黑嚕嚕粉圓店          台灣糖業股份有限公司
# 來源(產地)  臺北市萬華區國興路52號1樓(青年公園附近)  台中市大里區仁德里四維街29巷15號1樓  台南市仁德區田厝里文華路2段326號
#
#                     3               4               5                   6     \
# 夜市名稱               南機場夜市           南機場夜市           南機場夜市               南機場夜市
# 攤商名稱                肉羹涼麵            肉羹涼麵            肉羹涼麵                天品滷味
# 攤位        中華路二段309-311巷間  中華路二段309-311巷間  中華路二段309-311巷間      中華路二段307-309巷間
# 調味名稱                  香油              醬油               鹽                  胡椒
# ...

# %%
df_index_json = pd.read_json('foodtracer_nightmarket_merge.json', orient='index')

# %%
df_index_json
# Out:
#         夜市名稱   攤商名稱               攤位 調味名稱          品牌                  來源(產地)
# 0      南機場夜市  正宗福州麵       中華路二段315巷口    薑        青禾商行  臺北市萬華區國興路52號1樓(青年公園附近)
# 1      南機場夜市  黑嚕嚕粉圓   中華路二段307-309巷間   黑糖      黑嚕嚕粉圓店    台中市大里區仁德里四維街29巷15號1樓
# 2      南機場夜市   肉羹涼麵   中華路二段309-311巷間   冰糖  台灣糖業股份有限公司      台南市仁德區田厝里文華路2段326號
# 3      南機場夜市   肉羹涼麵   中華路二段309-311巷間   香油    辰邦股份有限公司        新北市新莊區化成路403巷47號
# 4      南機場夜市   肉羹涼麵   中華路二段309-311巷間   醬油  金蘭食品股份有限公司           桃園市大溪區介壽路236號
# ...      ...    ...              ...  ...         ...                     ...
# 3372  延三觀光夜市   阿春粥店  台北市大同區延平北路三段59號   醬油         龜甲萬         台南市新市區大營里大營7-2號
# 3373  延三觀光夜市   阿春粥店  台北市大同區延平北路三段59號   紅糟          惠通            大同區迪化街一段175號
# 3374  延三觀光夜市   阿春粥店  台北市大同區延平北路三段59號   砂糖          台糖             雲林縣虎尾鎮中山路2號
# 3375  延三觀光夜市   阿春粥店  台北市大同區延平北路三段59號    鹽          台鹽           苗栗縣通霄鎮內烏里122號
# 3376  延三觀光夜市   阿春粥店  台北市大同區延平北路三段59號   米酒    台灣菸酒台中酒廠           台中市西屯區工業28路2號
#
# [3377 rows x 6 columns]

# %% [markdown]
# - ### clipboard

# %%
# https://www.ctbcbank.com/twrbo/zh_tw/dep_index/dep_ratequery/dep_foreign_rates.html
pd.read_clipboard()
# Out:
#              幣別     現金買匯     現金賣匯     即期買匯     即期賣匯    換匯
# 0    美元 美元 USD   32.0330  32.6500  32.3390  32.4390  立即換匯
# 1    日圓 日圓 JPY    0.2047   0.2142   0.2084   0.2124  立即換匯
# 2  人民幣 人民幣 CNY    4.2939   4.5229   4.4379   4.4859  立即換匯
# 3    港幣 港幣 HKD    4.0200   4.2040   4.1040   4.1640  立即換匯
# 4    歐元 歐元 EUR   33.8520  35.0350  34.3140  34.7140  立即換匯
# 5    澳幣 澳幣 AUD   20.5890  21.3780  20.8810  21.1010  立即換匯
# 6    英鎊 英鎊 GBP   39.3200  41.1900  40.1800  40.5800  立即換匯

# %% [markdown]
# ---

# %% [markdown]
# ## Output

# %%
df = pd.DataFrame({'a':[1,2,3], 'b':[2,3,4]})
df
# Out:
#    a  b
# 0  1  2
# 1  2  3
# 2  3  4

# %%
df.to_csv('output.csv', index=False)

# %%
df.to_json('output.json')

# %% [markdown]
# [--QUIZ--]
#
# 1. 用DataFrame讀取planet.csv
# 2. 查看資料總共有幾列
# 3. 查看所有欄位名稱
# 4. 各欄位空值總數
# 5. 各欄位非空值總數
